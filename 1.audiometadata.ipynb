# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./soundmeta.csv')

# %%
df
# Out:
#     index                                         track_name  \
# 0       0                                       Take It Back
# 1       1                                           Friction
# 2       2  SOULFUL GENERATION BY DJ DS (FRANCE) HOUSESTAT...
# 3       3                                          Back 2 Me
# 4       4                                       Rise With Me
# 5       5                                      Audiospektrum
# 6       6                                 Feel Good Renegade
# 7       7                                      Play [140BPM]
# 8       8  Halloween 2021 - FREE Public Domain Sample Pac...
# 9       9  SOULFUL GENERATION ON HOUSESTATION RADIO BY DJ...
# 10     10  NOW THAT'S WHAT I CALL FUNK 80S REMIXES MIX BY...
# 11     11                                           Paradise
# 12     12  NOW THAT'S WHAT I CALL FUNK 80S REMIXES MIX BY...
# 13     13                                     Machine Rhythm
# ...
